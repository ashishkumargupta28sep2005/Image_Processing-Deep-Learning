# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Loading an image using OpenCv

# %%
img=cv.imread("Transition.jpg")
plt.imshow(img)

# %%
img.shape
# Out:
# (1536, 1536, 3)

# %%
img[:450,:,:].shape
# Out:
# (450, 1536, 3)

# %%
plt.imshow(img[:450,:,:])

# %%
plt.imshow(img[455:1050,:,:])

# %%
plt.imshow(img[1050:,:,:])

# %%
plt.imshow(img[:,:1000,:])

# %%
plt.imshow(img[:455,:1000,:])

# %% [markdown]
# ### Extracting The Frame

# %%
import cv2 as cv
import matplotlib.pyplot as plt

# %%
img=cv.imread("Transition.jpg")
plt.imshow(img)

# %%
img.shape
# Out:
# (1536, 1536, 3)

# %%
r=img[:,:,0]
g=img[:,:,1]
b=img[:,:,2]

# %%
plt.imshow(r)

# %%
plt.imshow(g)

# %%
plt.imshow(b)
